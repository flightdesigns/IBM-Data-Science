# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Terrence Muir
# Aviation Data Scientist

# %% [markdown]
# "*I am interested in data science because it provides an objective means of making business decisions.*"

# %% [markdown]
# ### In cell 5 my code will calculate the sum of 25 and 25.

# %%
25+25
# Out:
# 50

# %% [markdown]
# 1. Python
# 2. RStudio
# 3. SQL

# %% [markdown]
# What is your favourite sport:
# - Footbal
# - Cricket
# - Hockey
